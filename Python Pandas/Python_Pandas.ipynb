# %% [markdown]
# # **Pandas**
# is an open-source, BSD-licensed Python library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language.Python with Pandas is used in a wide range of fields including academic and commercial domains including finance, economics, Statistics, analytics, etc.
#
# The name Pandas is derived from the word **Panel Data** – an Econometrics from Multidimensional data.
#
# In **2008**, developer **Wes McKinney** started developing pandas when in need of high performance, flexible tool for analysis of data.
#
# Prior to Pandas, Python was majorly used for **data munging and preparation**. It had very little contribution towards **data analysis**. Pandas solved this problem.
#
# Using Pandas, we can accomplish **five** typical steps in the processing and analysis of data, regardless of the origin of data — **load, prepare, manipulate, model, and analyze.**

# %% [markdown]
# ## **Key Features of Pandas**
# * Fast and efficient DataFrame object with default and customized indexing.
# * Tools for loading data into in-memory data objects from different file formats.
# * Data alignment and integrated handling of missing data.
# * Reshaping and pivoting of date sets.
# * Label-based slicing, indexing and subsetting of large data sets.
# * Columns from a data structure can be deleted or inserted.
# * Group by data for aggregation and transformations.
# * High performance merging and joining of data.
# * Time Series functionality.

# %% [markdown]
# ## **List of Topics in Python Pandas.**
# ### **(a) Series**       <br />
# ### **(b) DataFrame**    <br />
# ### **(c) Panel**        <br />

# %% [markdown]
# # **Series**
# **Series** is a one-dimensional labeled array capable of holding data of any type (integer, string, float, python objects, etc.). The axis labels are collectively called **index.**  <br /><br />
# # **Topics under Pandas Series.**
# **(1)** How to create
#        * using Dictionary
#        * using array
#        * using scalar value or constant.
# **(2)** Querying Data using Series.
#        *

# %% [markdown]
# A pandas Series can be created using the following **constructor** : −
#
# **pandas.Series( data, index, dtype)**

# %%
import pandas as pd
pd.Series?

# %%
#creating an empty series.
s=pd.Series()
print('s: ',s);print('\n')
# Out:
# s:  Series([], dtype: float64)

# %%
#creating array from array.
import numpy as np
a=np.arange(5)
snum=pd.Series(a)
print('snum: \n',snum);print('\n')
animals=['tiger','bear','snake']
s_animals=pd.Series(animals)
print('s_animals: \n',s_animals);print('\n')
animals_new=['tiger','bear','snake',None]
s_animals_new=pd.Series(animals_new)
print('s_animals-new: \n',s_animals_new);print('\n')
a1=np.array([11,22,44,None])
a1_p=pd.Series(a1)
print('a1_p: \n',a1_p);print('\n')
# Out:
# snum:
#  0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64
#
#
# s_animals:
#  0    tiger
# 1     bear
# 2    snake
# dtype: object
#
#
# s_animals-new:
#  0    tiger
# 1     bear
# 2    snake
# 3     None
# dtype: object
#
#
# a1_p:
#  0      11
# 1      22
# 2      44
# 3    None
# dtype: object

# %%
#we can specify the index too as mentioned in series constructor.
animals=['tiger','bear','snake']
animals_ind=pd.Series(animals,index=[11,22,33])
print('animals_ind: \n',animals_ind)
# Out:
# animals_ind:
#  11    tiger
# 22     bear
# 33    snake
# dtype: object

# %%
#Create a series using dictinoary.
#A dict can be passed as input and if no index is specified, then the dictionary keys are taken in a sorted order to construct index. 
#If index is passed, the values in data corresponding to the labels in the index will be pulled out.
sports = {'Archery': 'Bhutan',
          'Golf': 'Scotland',
          'Sumo': 'Japan',
          'Taekwondo': 'South Korea'}
sport_series=pd.Series(sports)
print('sport_series: \n',sport_series);print
# Out:
# sport_series:
#  Archery           Bhutan
# Golf            Scotland
# Sumo               Japan
# Taekwondo    South Korea
# dtype: object
# <function print>

# %%
#Observe − Dictionary keys are used to construct index.
data = {'a' : 0., 'b' : 1., 'c' : 2.}
s = pd.Series(data,index=['b','c','d','a'])
print('s: \n',s)
# Out:
# s:
#  b    1.0
# c    2.0
# d    NaN
# a    0.0
# dtype: float64

# %%
#11,12,13,14 are dictionary keys.
data = {'a' : 0., 'b' : 1., 'c' : 2.}
s = pd.Series(data,index=[11,12,13,14])
print('s: \n',s)
# Out:
# s:
#  11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# dtype: float64

# %%
#Create a Series from Scalar
#If data is a scalar value, an index must be provided. The value will be repeated to match the length of index
s = pd.Series(5, index=[0, 1, 2, 3])
print ('s: \n',s)
# Out:
# s:
#  0    5
# 1    5
# 2    5
# 3    5
# dtype: int64

# %% [markdown]
# **Querying data using series.**

# %%
import pandas as pd
s = pd.Series([1,2,3,4,5],index = ['a','b','c','d','e'])
print('s: \n',s);print('\n')
print('s[1]: \n',s[1]);print('\n')
print('s[3:]: \n',s[3:]);print('\n')
print("s['c']: \n",s['c']);print('\n')
print("s[['a','c','d']]: \n",s[['a','c','d']]);print('\n')
print('s.iloc[3]: \n',s.iloc[3]);print('\n')
# Out:
# s:
#  a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64
#
#
# s[1]:
#  2
#
#
# s[3:]:
#  d    4
# e    5
# dtype: int64
#
#
# s['c']:
#  3
#
#
# s[['a','c','d']]:
#  a    1
# c    3
# d    4
# dtype: int64
#
#
# s.iloc[3]:
#  4

# %%
s = pd.Series([100.00, 120.00, 101.00, 3.00])
print('s: \n',s);print('\n')
print('type(s): ',type(s))
# Out:
# s:
#  0    100.0
# 1    120.0
# 2    101.0
# 3      3.0
# dtype: float64
#
#
# type(s):  <class 'pandas.core.series.Series'>

# %%
from timeit import timeit
# %%timeit -n 100     #it accounts only for 
total=0
for i in s:
    total+=i
#print(total)
# Out:
#   File "<ipython-input-12-0f3f8d3a1caa>", line 2
#     %%timeit -n 100     #it accounts only for
#     ^
# SyntaxError: invalid syntax

# %%
import numpy as np 
# %timeit s = pd.Series(np.random.randint(0,1000,10000))
s.head()     #it prints only the top values.

# %%
len(s)

# %%
# %%timeit -n 100
summary = 0
for item in s:
    summary+=item

# %%
# %%timeit -n 100
summary = np.sum(s)  #numpy is always faster

# %%
s+=2 #adds two to each item in s using broadcasting
s.head()

# %%
for label, value in s.iteritems():
    print(label,value)

# %%
for label, value in s.iteritems():  #you can add 2 to each item by this way too.since it's a dictionary.
    s.set_value(label, value+2)
s.head()

# %%
# %%timeit -n 10                      #here 10 is a number of values.
s = pd.Series(np.random.randint(0,1000,10000))
for label, value in s.iteritems():
    s.loc[label]= value+2

# %%
# %%timeit -n 10
s = pd.Series(np.random.randint(0,1000,10000))
s+=2

# %%
s = pd.Series([1, 2, 3])      #it's a way of adding value to dictionary or series.
s.loc['Animal'] = 'Bears'
print('s: \n',s)

# %%
original_sports = pd.Series({'Archery': 'Bhutan',
                             'Golf': 'Scotland',
                             'Sumo': 'Japan',
                             'Taekwondo': 'South Korea'})
cricket_loving_countries = pd.Series(['Australia',
                                      'Barbados',
                                      'Pakistan',
                                      'England'], 
                                   index=['Cricket',
                                          'Cricket',
                                          'Cricket',
                                          'Cricket'])
all_countries = original_sports.append(cricket_loving_countries) #this is how you can append values into different series at the same time.

# %%
original_sports

# %%
cricket_loving_countries

# %%
all_countries

# %% [markdown]
# # **DataFrame**
# A Data frame is a **two-dimensional data structure**, i.e., data is aligned in a **tabular fashion** in rows and columns.
#
# **Features of DataFrame**
#  * Potentially columns are of different types
#  * Size – Mutable
#  * Labeled axes (rows and columns)
#  * Can Perform Arithmetic operations on rows and columns
#
# **Topics in Pandas DataFrame.**
# * How to create DataFrame.
# * Create a DataFrame from Dict of ndarrays / Lists.
# * Create a DataFrame from List of Dicts.
# * Create a DataFrame from Dict of Series.
# * Perform operation in DataFrame made from Series.
#
# A pandas **DataFrame** can be created using the following constructor −
#
# **pandas.DataFrame( data, index, columns, dtype)**

# %%
import pandas as pd
df=pd.DataFrame()
print('df: ',df);print('\n')
print('type(df): ',type(df));print('\n')

# %%
#creating dataframe from lists.
l = [1,2,3,4,5]
l1=['tiger','bear','lion',None]
d= pd.DataFrame(data)
print('d: \n',d);print('\n')
d1= pd.DataFrame(l1)
print('d1: \n',d1);print('\n')
l2 = [['Alex',10],['Bob',12],['Clarke',13]]
d2 = pd.DataFrame(l2,columns=['Name','Age'])
print('d2: \n',d2);print('\n')
d3 = pd.DataFrame(l2,columns=['Name','Age'],dtype=float)
print('d3: \n',d3);print('\n')

# %%
#Create a DataFrame from Dict of ndarrays / Lists
#All the ndarrays must be of same length. If index is passed, then the length of the index should equal to the length of the arrays.
#If no index is passed, then by default, index will be range(n), where n is the array length.
d = {'Name':['Ram', 'Shyam', 'Dam', 'dharmu'],'Age':[28,34,29,42]}
df = pd.DataFrame(d)
print('df: \n',df)

# %%
import pandas as pd
purchase_1 = pd.Series({'Name': 'Chris',
                        'Item Purchased': 'Dog Food',
                        'Cost': 22.50})
purchase_2 = pd.Series({'Name': 'Kevyn',
                        'Item Purchased': 'Kitty Litter',
                        'Cost': 2.50})
purchase_3 = pd.Series({'Name': 'Vinod',
                        'Item Purchased': 'Bird Seed',
                        'Cost': 5.00})
df_c = pd.DataFrame([purchase_1, purchase_2, purchase_3], index=['Store 1', 'Store 1', 'Store 2'])
print('df_c: \n',df_c);print('\n')
print('df_c.head(): \n',df_c.head());print('\n')
print("type(df_c.loc['Store 2']) :",type(df_c.loc['Store 2']))  #it's a series.

# %%
df_c.loc['Store 1']  #this is called redundancy

# %%
df_c['Item Purchased']

# %%
df_c.T    #it gives you the transpose of the dataFrame

# %%
#indexed data fram from dict
d = {'Name':['Ram', 'Shyam', 'Dam', 'dharmu'],'Age':[28,34,29,42]}
df = pd.DataFrame(d, index=['rank1','rank2','rank3','rank4'])
print('df: \n',df)

# %%
df.loc['rank1','Age']   #getting a specific value

# %%
df.loc['rank1']['Age']   #getting a specific value

# %%
df.drop('rank1')

# %%
#List of Dictionaries can be passed as input data to create a DataFrame. The dictionary keys are by default taken as column names.
import pandas as pd
d= [{'a': 1, 'b': 2},{'a': 5, 'b': 10, 'c': 20}]
df = pd.DataFrame(d)
print('df: \n',df);print('\n')
df1 = pd.DataFrame(d, index=['first', 'second'])
print('df1: \n',df1);print('\n')
d1= [{'a': 1, 'b': 2},{'e': 5, 'f': 10, 'g': 20}]
df2 = pd.DataFrame(d1, index=['first', 'second'])
print('df1: \n',df2);print('\n')

# %%
import pandas as pd
data = [{'a': 1, 'b': 2},{'a': 5, 'b': 10, 'c': 20}]

#With two column indices, values same as dictionary keys
df1 = pd.DataFrame(data, index=['first', 'second'], columns=['a', 'b'])

#With two column indices with one index with other name
df2 = pd.DataFrame(data, index=['first', 'second'], columns=['a', 'b1'])
print('df1: \n',df1);print('\n')
print('df2: \n',df2);print('\n')

# %%
#Dictionary of Series can be passed to form a DataFrame. 
#The resultant index is the union of all the series indexes passed.
import pandas as pd

d = {'one' : pd.Series([1, 2, 3], index=['a', 'b', 'c']),
      'two' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])}

df = pd.DataFrame(d)
print('df: \n',df);print('\n')
print("df['one']: \n",df['one'])

# %%
#Column Addition
import pandas as pd

d = {'one' : pd.Series([1, 2, 3], index=['a', 'b', 'c']),
      'two' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])}

df = pd.DataFrame(d)

# Adding a new column to an existing DataFrame object with column label by passing new series

df['three']=pd.Series([10,20,30],index=['a','b','c'])  #Adding a new column by passing as Series
print('df: \n',df);print('\n')

df['four']=df['one']+df['three']  #Adding a new column using the existing columns in DataFrame
print('df: \n',df)

# %%
#deleting and poping operation on dataFrames.
import pandas as pd

d = {'one' : pd.Series([1, 2, 3], index=['a', 'b', 'c']), 
     'two' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd']), 
     'three' : pd.Series([10,20,30], index=['a','b','c'])}

df = pd.DataFrame(d)
print('df: \n',df);print('\n')

# using del function
print ("Deleting the first column using DEL function:")
del df['one']
print('df: \n',df);print('\n')

# using pop function
print ("Deleting another column using POP function:")
df.pop('two')
print('df: \n',df);print('\n')

# %%
#Row Selection, Addition, and Deletion in DataFrame.
#We will now understand row selection, addition and deletion through examples. 
import pandas as pd

d = {'one' : pd.Series([1, 2, 3], index=['a', 'b', 'c']), 
     'two' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])}

df = pd.DataFrame(d)
print('df: \n',df);print('\n')
print("df['one']: \n",df['one']);print('\n')
print("df.iloc[2]: \n",df.iloc[2]);print('\n')    #this selects second index
print("df.loc['b']: \n",df.loc['b']);print('\n')  #this selects the index b
print('df[2:4]: \n',df[2:4]);print('\n')

# %%
import pandas as pd

df = pd.DataFrame([[1, 2], [3, 4]], columns = ['a','b'])
print('df: \n',df);print('\n')
df2 = pd.DataFrame([[5, 6], [7, 8]], columns = ['a','b'])
print('df: \n',df);print('\n')
df = df.append(df2)
print('df: \n',df);print('\n')
df=df.drop(0) #drops the df with label 0
print('df: \n',df);print('\n')

# %%
df_c

# %%
costs=df_c['Cost']
costs

# %%
costs+=2  #it increases the value of costs by 2
costs

# %%
df_c  #hence as we can original data in dataframe is changed too

# %%
df_c1=df_c
df_c1

# %%
id(df_c1)

# %%
id(df_c)                       
#as the id doesn't changes for new dataframe so that changes in new dataframe will have affect the original.
#that's the reason we'll gonna use copy() function to change the id(or location in primary memory.)

# %%
df_c2=df_c.copy()          #copy() function changes the id of original function.
print('df_c2: \n',df_c2);print('\n')
print('id(df_c): ',id(df_c))
print('id(df_c2): ',id(df_c2))

# %%
#deleting a column from copy.
del df_c2['Name']

# %%
df_c2['location']=None
df_c2

# %%
#playing with the csv files
# !cat olympics.csv

# %%
df_olympics=pd.read_csv('olympics.csv')
df_olympics.head()

# %%
#but as we can see in above dataframe that first rows is a problem with values we don't want as values but columns.
df_olympics=pd.read_csv('olympics.csv',index_col=0,skiprows=1)
df_olympics.head()

# %%
#now as we can see column values are repeated which isn't a good thing.
print(df_olympics.columns)  #this function stores all the column values.
print(type(df_olympics.columns))

# %%
for col in df_olympics.columns:
    if col[:2]=='01':
        df_olympics.rename(columns={col:'Gold' + col[4:]}, inplace=True)
    if col[:2]=='02':
        df_olympics.rename(columns={col:'Silver' + col[4:]}, inplace=True)
    if col[:2]=='03':
        df_olympics.rename(columns={col:'Bronze' + col[4:]}, inplace=True)
    if col[:1]=='№':
        df_olympics.rename(columns={col:'#' + col[1:]}, inplace=True) 

df_olympics.head()

# %%
#now we'll perform boolean masking on the data.
#boolean masking allows us to filter out the columns or data in general
#it's very fast.
df_olympics['Gold']>0   #this will filter only the countries with gold greater than 0 with true or false

# %%
only_gold_win=df_olympics.where(df_olympics['Gold']>0)
only_gold_win.head()  #so countries who didn't win any gold would return Nan for them.
#remember we're playing only for summer games.

# %%
only_gold_win['Gold'].count()

# %%
df_olympics['Gold'].count()

# %%
#if we want to drop the countries who didn't win any gold in summer olympics.then use dropna() function
only_gold_win_filter=only_gold_win.dropna()
only_gold_win_filter.head()

# %%
len(only_gold_win_filter)

# %%
len(df_olympics[(df_olympics['Gold'] > 0) | (df_olympics['Gold.1'] > 0)])

# %%
len(df_olympics[(df_olympics['Gold'] == 0) | (df_olympics['Gold.1'] > 0)])

# %%
df_olympics[(df_olympics['Gold.1'] > 0) & (df_olympics['Gold'] == 0)]

# %%
#now suppose we don't want to indices to be country but anything else.
#but we can find add new index or replace the index using setindex function but it's adivsed not to use it 
#because it doesn't keep the current index.
#now let's index the data by gold medals at summer olympics.
df_olympics['Country']=df_olympics.index  #this preserves the current index viz. a list of names of countries.
df_olympics=df_olympics.set_index('Gold') #setting gold column as the index column
df_olympics.head()
#but as we can see it created a new index or a empty row because of name of column i.e Gold

# %%
#now the gold is a index but not a permanent or default index so we need to use reset_index() function.
df_olympics=df_olympics.reset_index()
df_olympics.head()

# %%
#now let's play with a new datasets which is census of USA
df_census = pd.read_csv('census.csv')
df_census.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780127          4785161     ...
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0          0.002295         -0.193196          0.381066          0.582002
# ...

# %%
#if we want to find only the unique values of SUMLEV like in sql then use unique() function.
df_census['SUMLEV'].unique()
# Out:
# array([40, 50])

# %%
#now let's reduce the region with only SUMLEV of 50.
df_sumlev50=df_census[df_census['SUMLEV']==50]
df_sumlev50.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
# 5          57322              57322            57373     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 1          7.242091         -2.915927         -3.012349          2.265971
# ...

# %%
#this is the list of columns they have.
df_census.columns
# Out:
# Index(['SUMLEV', 'REGION', 'DIVISION', 'STATE', 'COUNTY', 'STNAME', 'CTYNAME',
#        'CENSUS2010POP', 'ESTIMATESBASE2010', 'POPESTIMATE2010',
#        'POPESTIMATE2011', 'POPESTIMATE2012', 'POPESTIMATE2013',
#        'POPESTIMATE2014', 'POPESTIMATE2015', 'NPOPCHG_2010', 'NPOPCHG_2011',
#        'NPOPCHG_2012', 'NPOPCHG_2013', 'NPOPCHG_2014', 'NPOPCHG_2015',
#        'BIRTHS2010', 'BIRTHS2011', 'BIRTHS2012', 'BIRTHS2013', 'BIRTHS2014',
#        'BIRTHS2015', 'DEATHS2010', 'DEATHS2011', 'DEATHS2012', 'DEATHS2013',
#        'DEATHS2014', 'DEATHS2015', 'NATURALINC2010', 'NATURALINC2011',
#        'NATURALINC2012', 'NATURALINC2013', 'NATURALINC2014', 'NATURALINC2015',
#        'INTERNATIONALMIG2010', 'INTERNATIONALMIG2011', 'INTERNATIONALMIG2012',
#        'INTERNATIONALMIG2013', 'INTERNATIONALMIG2014', 'INTERNATIONALMIG2015',
#        'DOMESTICMIG2010', 'DOMESTICMIG2011', 'DOMESTICMIG2012',
#        'DOMESTICMIG2013', 'DOMESTICMIG2014', 'DOMESTICMIG2015', 'NETMIG2010',
# ...

# %%
#now let's filter out the specific columns.
columns_to_keep = ['STNAME',
                   'CTYNAME',
                   'BIRTHS2010',
                   'BIRTHS2011',
                   'BIRTHS2012',
                   'BIRTHS2013',
                   'BIRTHS2014',
                   'BIRTHS2015',
                   'POPESTIMATE2010',
                   'POPESTIMATE2011',
                   'POPESTIMATE2012',
                   'POPESTIMATE2013',
                   'POPESTIMATE2014',
                   'POPESTIMATE2015']
df_new=df_sumlev50[columns_to_keep]
df_new.head()  #it is designed in a way we want.
# Out:
#     STNAME         CTYNAME  BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# 1  Alabama  Autauga County         151         636         615         574
# 2  Alabama  Baldwin County         517        2187        2092        2160
# 3  Alabama  Barbour County          70         335         300         283
# 4  Alabama     Bibb County          44         266         245         259
# 5  Alabama   Blount County         183         744         710         646
#
#    BIRTHS2014  BIRTHS2015  POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  \
# 1         623         600            54660            55253            55175
# 2        2186        2240           183193           186659           190396
# 3         260         269            27341            27226            27159
# 4         247         253            22861            22733            22642
# 5         618         603            57373            57711            57776
#
# ...

# %%
#now let's change the index by statename and countyname
df_new = df_new.set_index(['STNAME', 'CTYNAME'])
df_new
# Out:
#                               BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME    CTYNAME
# Alabama   Autauga County             151         636         615         574
#           Baldwin County             517        2187        2092        2160
#           Barbour County              70         335         300         283
#           Bibb County                 44         266         245         259
#           Blount County              183         744         710         646
#           Bullock County              39         169         122         132
#           Butler County               65         276         241         240
#           Calhoun County             317        1382        1357        1309
#           Chambers County             81         401         393         404
#           Cherokee County             55         221         245         232
#           Chilton County             124         565         565         537
# ...

# %%
df_new.loc['Michigan', 'Washtenaw County']

# %%
df_new.loc[ [('Michigan', 'Washtenaw County'),
         ('Michigan', 'Wayne County')] ]

# %%
#now let's play with a new file viz is log file.
df_log=pd.read_csv('log.csv')
df_log.head()

# %%
df_log.fillna?

# %%
df_log = df_log.set_index('time')
df_log = df_log.sort_index()
df_log

# %%
df_log = df_log.reset_index()
df_log = df_log.set_index(['time', 'user'])
df_log

# %% [markdown]
# ### Merging DataFrames.

# %%
import pandas as pd

df = pd.DataFrame([{'Name': 'Chris', 'Item Purchased': 'Sponge', 'Cost': 22.50},
                   {'Name': 'Kevyn', 'Item Purchased': 'Kitty Litter', 'Cost': 2.50},
                   {'Name': 'Filip', 'Item Purchased': 'Spoon', 'Cost': 5.00}],
                  index=['Store 1', 'Store 1', 'Store 2'])
df
# Out:
#          Cost Item Purchased   Name
# Store 1  22.5         Sponge  Chris
# Store 1   2.5   Kitty Litter  Kevyn
# Store 2   5.0          Spoon  Filip

# %%
#add new column to dataframe
df['Date']=['December 1','January 1','May 4'] #as long as the size is same.
df['Delivered'] = True
df['Feedback'] = ['Positive', None, 'Negative']
df
# Out:
#          Cost Item Purchased   Name        Date  Delivered  Feedback
# Store 1  22.5         Sponge  Chris  December 1       True  Positive
# Store 1   2.5   Kitty Litter  Kevyn   January 1       True      None
# Store 2   5.0          Spoon  Filip       May 4       True  Negative

# %%
adf = df.reset_index()
adf['Date'] = pd.Series({0: 'December 1', 2: 'mid-May'})
adf
# Out:
#      index  Cost Item Purchased   Name        Date  Delivered  Feedback
# 0  Store 1  22.5         Sponge  Chris  December 1       True  Positive
# 1  Store 1   2.5   Kitty Litter  Kevyn         NaN       True      None
# 2  Store 2   5.0          Spoon  Filip     mid-May       True  Negative

# %%
staff_df = pd.DataFrame([{'Name': 'Kelly', 'Role': 'Director of HR'},
                         {'Name': 'Sally', 'Role': 'Course liasion'},
                         {'Name': 'James', 'Role': 'Grader'}])
staff_df = staff_df.set_index('Name')
student_df = pd.DataFrame([{'Name': 'James', 'School': 'Business'},
                           {'Name': 'Mike', 'School': 'Law'},
                           {'Name': 'Sally', 'School': 'Engineering'}])
student_df = student_df.set_index('Name')
print(staff_df.head())
print(student_df.head())
# Out:
#                  Role
# Name
# Kelly  Director of HR
# Sally  Course liasion
# James          Grader
#             School
# Name
# James     Business
# Mike           Law
# Sally  Engineering

# %%
#now we'll merge both the dataframes using outer join or union using .merge() unction.
pd.merge(staff_df, student_df, how='outer', left_index=True, right_index=True)
# Out:
#                  Role       School
# Name
# James          Grader     Business
# Kelly  Director of HR          NaN
# Mike              NaN          Law
# Sally  Course liasion  Engineering

# %%
#use inner method in how to get inner join or intersection
pd.merge(staff_df, student_df, how='inner', left_index=True, right_index=True)
# Out:
#                  Role       School
# Name
# Sally  Course liasion  Engineering
# James          Grader     Business

# %%
pd.merge(staff_df, student_df, how='left', left_index=True, right_index=True)
# Out:
#                  Role       School
# Name
# Kelly  Director of HR          NaN
# Sally  Course liasion  Engineering
# James          Grader     Business

# %%
pd.merge(staff_df, student_df, how='right', left_index=True, right_index=True)
# Out:
#                  Role       School
# Name
# James          Grader     Business
# Mike              NaN          Law
# Sally  Course liasion  Engineering

# %%
staff_df = staff_df.reset_index()
student_df = student_df.reset_index()
print(staff_df.head())
print(student_df.head())

# %%
pd.merge(staff_df, student_df, how='left', left_on='Name', right_on='Name')
# Out:
#     Name            Role       School
# 0  Kelly  Director of HR          NaN
# 1  Sally  Course liasion  Engineering
# 2  James          Grader     Business

# %%
staff_df = pd.DataFrame([{'Name': 'Kelly', 'Role': 'Director of HR', 'Location': 'State Street'},
                         {'Name': 'Sally', 'Role': 'Course liasion', 'Location': 'Washington Avenue'},
                         {'Name': 'James', 'Role': 'Grader', 'Location': 'Washington Avenue'}])
student_df = pd.DataFrame([{'Name': 'James', 'School': 'Business', 'Location': '1024 Billiard Avenue'},
                           {'Name': 'Mike', 'School': 'Law', 'Location': 'Fraternity House #22'},
                           {'Name': 'Sally', 'School': 'Engineering', 'Location': '512 Wilson Crescent'}])
print(staff_df.head())
print(student_df.head())
# Out:
#             Location   Name            Role
# 0       State Street  Kelly  Director of HR
# 1  Washington Avenue  Sally  Course liasion
# 2  Washington Avenue  James          Grader
#                Location   Name       School
# 0  1024 Billiard Avenue  James     Business
# 1  Fraternity House #22   Mike          Law
# 2   512 Wilson Crescent  Sally  Engineering

# %%
#now as we know from above data frames that location is conflicting as all values are different..
#so it automatically changes the location or it'll split up the locations.
pd.merge(staff_df, student_df, how='inner', left_on='Name', right_on='Name')
# Out:
#           Location_x   Name            Role            Location_y       School
# 0  Washington Avenue  Sally  Course liasion   512 Wilson Crescent  Engineering
# 1  Washington Avenue  James          Grader  1024 Billiard Avenue     Business

# %%
staff_df = pd.DataFrame([{'First Name': 'Kelly', 'Last Name': 'Desjardins', 'Role': 'Director of HR'},
                         {'First Name': 'Sally', 'Last Name': 'Brooks', 'Role': 'Course liasion'},
                         {'First Name': 'James', 'Last Name': 'Wilde', 'Role': 'Grader'}])
student_df = pd.DataFrame([{'First Name': 'James', 'Last Name': 'Hammond', 'School': 'Business'},
                           {'First Name': 'Mike', 'Last Name': 'Smith', 'School': 'Law'},
                           {'First Name': 'Sally', 'Last Name': 'Brooks', 'School': 'Engineering'}])
staff_df
student_df
pd.merge(staff_df, student_df, how='inner', left_on=['First Name','Last Name'], right_on=['First Name','Last Name'])
#hence it'll match for both first name and last name and only sally would come outta it.
# Out:
#   First Name Last Name            Role       School
# 0      Sally    Brooks  Course liasion  Engineering

# %% [markdown]
# ### Panda's Idioms

# %%
import pandas as pd
df = pd.read_csv('census.csv')
df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY     STNAME             CTYNAME  \
# 0         40       3         6      1       0    Alabama             Alabama
# 1         50       3         6      1       1    Alabama      Autauga County
# 2         50       3         6      1       3    Alabama      Baldwin County
# 3         50       3         6      1       5    Alabama      Barbour County
# 4         50       3         6      1       7    Alabama         Bibb County
# 5         50       3         6      1       9    Alabama       Blount County
# 6         50       3         6      1      11    Alabama      Bullock County
# 7         50       3         6      1      13    Alabama       Butler County
# 8         50       3         6      1      15    Alabama      Calhoun County
# 9         50       3         6      1      17    Alabama     Chambers County
# 10        50       3         6      1      19    Alabama     Cherokee County
# ...

# %%
#method chaining is more pandorable viz a idiomatic or optmizable way of pandas coding than index chaining.
#method chaining means a series of methods developed in a single line.
(df.where(df['SUMLEV']==50)
    .dropna()
    .set_index(['STNAME','CTYNAME'])
    .rename(columns={'ESTIMATESBASE2010': 'Estimates Base 2010'}))
#the () brackets are just a simple way of bringing entire code together..even if we don't use..it'll work
# Out:
#                               SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME    CTYNAME
# Alabama   Autauga County        50.0     3.0       6.0    1.0     1.0
#           Baldwin County        50.0     3.0       6.0    1.0     3.0
#           Barbour County        50.0     3.0       6.0    1.0     5.0
#           Bibb County           50.0     3.0       6.0    1.0     7.0
#           Blount County         50.0     3.0       6.0    1.0     9.0
#           Bullock County        50.0     3.0       6.0    1.0    11.0
#           Butler County         50.0     3.0       6.0    1.0    13.0
#           Calhoun County        50.0     3.0       6.0    1.0    15.0
#           Chambers County       50.0     3.0       6.0    1.0    17.0
#           Cherokee County       50.0     3.0       6.0    1.0    19.0
#           Chilton County        50.0     3.0       6.0    1.0    21.0
#           Choctaw County        50.0     3.0       6.0    1.0    23.0
# ...

# %%
#the index method means using the code in beginner way by breaking it...but it isn't pandorable.
df = df[df['SUMLEV']==50]
df.set_index(['STNAME','CTYNAME'], inplace=True)
df.rename(columns={'ESTIMATESBASE2010': 'Estimates Base 2010'})
# Out:
#                               SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME    CTYNAME
# Alabama   Autauga County          50       3         6      1       1
#           Baldwin County          50       3         6      1       3
#           Barbour County          50       3         6      1       5
#           Bibb County             50       3         6      1       7
#           Blount County           50       3         6      1       9
#           Bullock County          50       3         6      1      11
#           Butler County           50       3         6      1      13
#           Calhoun County          50       3         6      1      15
#           Chambers County         50       3         6      1      17
#           Cherokee County         50       3         6      1      19
#           Chilton County          50       3         6      1      21
#           Choctaw County          50       3         6      1      23
# ...

# %%
import numpy as np
def min_max(row):
    data = row[['POPESTIMATE2010',
                'POPESTIMATE2011',
                'POPESTIMATE2012',
                'POPESTIMATE2013',
                'POPESTIMATE2014',
                'POPESTIMATE2015']]
    return pd.Series({'min': np.min(data), 'max': np.max(data)})

# %%
#apply is a function used to apply certain functionalities.
df.apply(min_max, axis=1)
# Out:
#                                    max       min
# STNAME    CTYNAME
# Alabama   Autauga County       55347.0   54660.0
#           Baldwin County      203709.0  183193.0
#           Barbour County       27341.0   26489.0
#           Bibb County          22861.0   22512.0
#           Blount County        57776.0   57373.0
#           Bullock County       10887.0   10606.0
#           Butler County        20944.0   20154.0
#           Calhoun County      118437.0  115620.0
#           Chambers County      34153.0   33993.0
#           Cherokee County      26084.0   25859.0
#           Chilton County       43943.0   43665.0
#           Choctaw County       13841.0   13170.0
#           Clarke County        25767.0   24675.0
#           Clay County          13880.0   13456.0
#           Cleburne County      15072.0   14921.0
#           Coffee County        51211.0   50177.0
#           Colbert County       54514.0   54354.0
#           Conecuh County       13208.0   12662.0
# ...

# %%
import numpy as np
def min_max(row):
    data = row[['POPESTIMATE2010',
                'POPESTIMATE2011',
                'POPESTIMATE2012',
                'POPESTIMATE2013',
                'POPESTIMATE2014',
                'POPESTIMATE2015']]
    row['max'] = np.max(data)
    row['min'] = np.min(data)
    return row
df.apply(min_max, axis=1)
# Out:
#                               SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME    CTYNAME
# Alabama   Autauga County        50.0     3.0       6.0    1.0     1.0
#           Baldwin County        50.0     3.0       6.0    1.0     3.0
#           Barbour County        50.0     3.0       6.0    1.0     5.0
#           Bibb County           50.0     3.0       6.0    1.0     7.0
#           Blount County         50.0     3.0       6.0    1.0     9.0
#           Bullock County        50.0     3.0       6.0    1.0    11.0
#           Butler County         50.0     3.0       6.0    1.0    13.0
#           Calhoun County        50.0     3.0       6.0    1.0    15.0
#           Chambers County       50.0     3.0       6.0    1.0    17.0
#           Cherokee County       50.0     3.0       6.0    1.0    19.0
#           Chilton County        50.0     3.0       6.0    1.0    21.0
#           Choctaw County        50.0     3.0       6.0    1.0    23.0
# ...

# %%
rows = ['POPESTIMATE2010',
        'POPESTIMATE2011',
        'POPESTIMATE2012',
        'POPESTIMATE2013',
        'POPESTIMATE2014',
        'POPESTIMATE2015']
df.apply(lambda x: np.max(x[rows]), axis=1)
# Out:
# STNAME     CTYNAME
# Alabama    Autauga County         55347.0
#            Baldwin County        203709.0
#            Barbour County         27341.0
#            Bibb County            22861.0
#            Blount County          57776.0
#            Bullock County         10887.0
#            Butler County          20944.0
#            Calhoun County        118437.0
#            Chambers County        34153.0
#            Cherokee County        26084.0
#            Chilton County         43943.0
#            Choctaw County         13841.0
#            Clarke County          25767.0
#            Clay County            13880.0
#            Cleburne County        15072.0
#            Coffee County          51211.0
#            Colbert County         54514.0
#            Conecuh County         13208.0
#            Coosa County           11758.0
#            Covington County       38060.0
#            Crenshaw County        13963.0
#            Cullman County         82005.0
# ...

# %% [markdown]
# ### Groupby in DataFrame

# %%
#first approach without using groupby function.
import pandas as pd
import numpy as np
df = pd.read_csv('census.csv')
df = df[df['SUMLEV']==50]
df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY     STNAME             CTYNAME  \
# 1         50       3         6      1       1    Alabama      Autauga County
# 2         50       3         6      1       3    Alabama      Baldwin County
# 3         50       3         6      1       5    Alabama      Barbour County
# 4         50       3         6      1       7    Alabama         Bibb County
# 5         50       3         6      1       9    Alabama       Blount County
# 6         50       3         6      1      11    Alabama      Bullock County
# 7         50       3         6      1      13    Alabama       Butler County
# 8         50       3         6      1      15    Alabama      Calhoun County
# 9         50       3         6      1      17    Alabama     Chambers County
# 10        50       3         6      1      19    Alabama     Cherokee County
# 11        50       3         6      1      21    Alabama      Chilton County
# ...

# %%
# %%timeit -n 10
for state in df['STNAME'].unique():
    avg = np.average(df.where(df['STNAME']==state).dropna()['CENSUS2010POP'])
    print('Counties in state ' + state + ' have an average population of ' + str(avg))
# Out:
# Counties in state Alabama have an average population of 71339.3432836
# Counties in state Alaska have an average population of 24490.7241379
# Counties in state Arizona have an average population of 426134.466667
# Counties in state Arkansas have an average population of 38878.9066667
# Counties in state California have an average population of 642309.586207
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.567164
# Counties in state Georgia have an average population of 60928.6352201
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.8636364
# ...

# %%
# %%timeit -n 10
for group, frame in df.groupby('STNAME'):
    avg = np.average(frame['CENSUS2010POP'])
    print('Counties in state ' + group + ' have an average population of ' + str(avg))
# Out:
# Counties in state Alabama have an average population of 71339.3432836
# Counties in state Alaska have an average population of 24490.7241379
# Counties in state Arizona have an average population of 426134.466667
# Counties in state Arkansas have an average population of 38878.9066667
# Counties in state California have an average population of 642309.586207
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.567164
# Counties in state Georgia have an average population of 60928.6352201
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.8636364
# ...

# %%
df = df.set_index('STNAME')

def fun(item):
    if item[0]<'M':
        return 0
    if item[0]<'Q':
        return 1
    return 2

for group, frame in df.groupby(fun):
    print('There are ' + str(len(frame)) + ' records in group ' + str(group) + ' for processing.')
# Out:
# There are 1177 records in group 0 for processing.
# There are 1134 records in group 1 for processing.
# There are 831 records in group 2 for processing.

# %%
df = pd.read_csv('census.csv')
df = df[df['SUMLEV']==50]

# %%
df.groupby('STNAME').agg({'CENSUS2010POP': np.average})
# Out:
#                       CENSUS2010POP
# STNAME
# Alabama                71339.343284
# Alaska                 24490.724138
# Arizona               426134.466667
# Arkansas               38878.906667
# California            642309.586207
# Colorado               78581.187500
# Connecticut           446762.125000
# Delaware              299311.333333
# District of Columbia  601723.000000
# Florida               280616.567164
# Georgia                60928.635220
# Hawaii                272060.200000
# Idaho                  35626.863636
# Illinois              125790.509804
# Indiana                70476.108696
# Iowa                   30771.262626
# Kansas                 27172.552381
# Kentucky               36161.391667
# Louisiana              70833.937500
# Maine                  83022.562500
# Maryland              240564.666667
# Massachusetts         467687.785714
# Michigan              119080.000000
# Minnesota              60964.655172
# Mississippi            36186.548780
# ...

# %%
print(type(df.groupby(level=0)['POPESTIMATE2010','POPESTIMATE2011']))
print(type(df.groupby(level=0)['POPESTIMATE2010']))
# Out:
# <class 'pandas.core.groupby.DataFrameGroupBy'>
# <class 'pandas.core.groupby.SeriesGroupBy'>

# %%
(df.set_index('STNAME').groupby(level=0)['CENSUS2010POP']
    .agg({'avg': np.average, 'sum': np.sum}))
# Out:
# /home/dammonoit/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#                                 avg       sum
# STNAME
# Alabama                71339.343284   4779736
# Alaska                 24490.724138    710231
# Arizona               426134.466667   6392017
# Arkansas               38878.906667   2915918
# California            642309.586207  37253956
# Colorado               78581.187500   5029196
# Connecticut           446762.125000   3574097
# Delaware              299311.333333    897934
# District of Columbia  601723.000000    601723
# Florida               280616.567164  18801310
# Georgia                60928.635220   9687653
# Hawaii                272060.200000   1360301
# Idaho                  35626.863636   1567582
# Illinois              125790.509804  12830632
# Indiana                70476.108696   6483802
# ...

# %%
(df.set_index('STNAME').groupby(level=0)['POPESTIMATE2010','POPESTIMATE2011']
    .agg({'avg': np.average, 'sum': np.sum}))
# Out:
# /home/dammonoit/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py:3961: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#                                  avg                             sum  \
#                      POPESTIMATE2010 POPESTIMATE2011 POPESTIMATE2010
# STNAME
# Alabama                 71420.313433    71658.328358         4785161
# Alaska                  24621.413793    24921.379310          714021
# Arizona                427213.866667   431248.800000         6408208
# Arkansas                38965.253333    39180.506667         2922394
# California             643691.017241   650000.586207        37334079
# Colorado                78878.968750    79991.875000         5048254
# Connecticut            447464.625000   448719.875000         3579717
# Delaware               299930.333333   302638.666667          899791
# ...

# %% [markdown]
# ### Scales

# %%
import pandas as pd
df = pd.DataFrame(['A+', 'A', 'A-', 'B+', 'B', 'B-', 'C+', 'C', 'C-', 'D+', 'D'],
                  index=['excellent', 'excellent', 'excellent', 'good', 'good', 'good', 'ok', 'ok', 'ok', 'poor', 'poor'])
df.rename(columns={0: 'Grades'}, inplace=True)
df
# Out:
#           Grades
# excellent     A+
# excellent      A
# excellent     A-
# good          B+
# good           B
# good          B-
# ok            C+
# ok             C
# ok            C-
# poor          D+
# poor           D

# %%
df['Grades'].astype('category')
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# good         B-
# ok           C+
# ok            C
# ok           C-
# poor         D+
# poor          D
# Name: Grades, dtype: category
# Categories (11, object): [A, A+, A-, B, ..., C+, C-, D, D+]

# %%
grades = df['Grades'].astype('category',
                             categories=['D', 'D+', 'C-', 'C', 'C+', 'B-', 'B', 'B+', 'A-', 'A', 'A+'],
                             ordered=True)
grades
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# good         B-
# ok           C+
# ok            C
# ok           C-
# poor         D+
# poor          D
# Name: Grades, dtype: category
# Categories (11, object): [D < D+ < C- < C ... B+ < A- < A < A+]

# %%
grades > 'C'
# Out:
# excellent     True
# excellent     True
# excellent     True
# good          True
# good          True
# good          True
# ok            True
# ok           False
# ok           False
# poor         False
# poor         False
# Name: Grades, dtype: bool

# %%
import numpy as np
df = pd.read_csv('census.csv')
df = df[df['SUMLEV']==50]
df = df.set_index('STNAME').groupby(level=0)['CENSUS2010POP'].agg({'avg': np.average})
pd.cut(df['avg'],10)
# Out:
# /home/dammonoit/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   after removing the cwd from sys.path.
# STNAME
# Alabama                   (11706.087, 75333.413]
# Alaska                    (11706.087, 75333.413]
# Arizona                 (390320.176, 453317.529]
# Arkansas                  (11706.087, 75333.413]
# California              (579312.234, 642309.586]
# Colorado                 (75333.413, 138330.766]
# Connecticut             (390320.176, 453317.529]
# Delaware                (264325.471, 327322.823]
# District of Columbia    (579312.234, 642309.586]
# Florida                 (264325.471, 327322.823]
# Georgia                   (11706.087, 75333.413]
# Hawaii                  (264325.471, 327322.823]
# Idaho                     (11706.087, 75333.413]
# Illinois                 (75333.413, 138330.766]
# ...

# %% [markdown]
# ### Pivot Tables

# %%
df = pd.read_csv('cars.csv')
df.head()
# Out:
#    YEAR        Make           Model        Size  (kW) Unnamed: 5 TYPE  \
# 0  2012  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 1  2012      NISSAN            LEAF    MID-SIZE    80         A1    B
# 2  2013        FORD  FOCUS ELECTRIC     COMPACT   107         A1    B
# 3  2013  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 4  2013      NISSAN            LEAF    MID-SIZE    80         A1    B
#
#    CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  CITY (Le/100 km)  \
# 0               16.9              21.4               18.7               1.9
# 1               19.3              23.0               21.1               2.2
# 2               19.0              21.1               20.0               2.1
# 3               16.9              21.4               18.7               1.9
# 4               19.3              23.0               21.1               2.2
#
#    HWY (Le/100 km)  COMB (Le/100 km)  (g/km) RATING  (km)  TIME (h)
# ...

# %%
df.pivot_table(values='(kW)', index='YEAR', columns='Make', aggfunc=np.mean)
# Out:
# Make    BMW  CHEVROLET   FORD   KIA  MITSUBISHI  NISSAN  SMART       TESLA
# YEAR
# 2012    NaN        NaN    NaN   NaN        49.0    80.0    NaN         NaN
# 2013    NaN        NaN  107.0   NaN        49.0    80.0   35.0  280.000000
# 2014    NaN      104.0  107.0   NaN        49.0    80.0   35.0  268.333333
# 2015  125.0      104.0  107.0  81.0        49.0    80.0   35.0  320.666667
# 2016  125.0      104.0  107.0  81.0        49.0    80.0   35.0  409.700000

# %% [markdown]
# ## Date Functionality in Pandas
#
# ### Timestamp

# %%
import pandas as pd
import numpy as np
pd.Timestamp('9/1/2016 10:05AM')
# Out:
# Timestamp('2016-09-01 10:05:00')

# %% [markdown]
# ### Period

# %%
pd.Period('1/2016')
# Out:
# Period('2016-01', 'M')

# %%
pd.Period('3/5/2016')
# Out:
# Period('2016-03-05', 'D')

# %% [markdown]
# ### DatetimeIndex

# %%
t1 = pd.Series(['Shopping','Playing','Movie'], [pd.Timestamp('2016-09-01'), pd.Timestamp('2016-09-02'), pd.Timestamp('2016-09-03')])
t1
# Out:
# 2016-09-01    Shopping
# 2016-09-02     Playing
# 2016-09-03       Movie
# dtype: object

# %%
t1 = pd.Series(list('abc'), [pd.Timestamp('2016-09-01'), pd.Timestamp('2016-09-02'), pd.Timestamp('2016-09-03')])
t1
# Out:
# 2016-09-01    a
# 2016-09-02    b
# 2016-09-03    c
# dtype: object

# %%
t1.index
# Out:
# DatetimeIndex(['2016-09-01', '2016-09-02', '2016-09-03'], dtype='datetime64[ns]', freq=None)

# %%
type(t1.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %% [markdown]
# ### PeriodIndex

# %%
t2 = pd.Series(list('def'), [pd.Period('2016-09'), pd.Period('2016-10'), pd.Period('2016-11')])
t2
# Out:
# 2016-09    d
# 2016-10    e
# 2016-11    f
# Freq: M, dtype: object

# %%
type(t2.index)
# Out:
# pandas.core.indexes.period.PeriodIndex

# %% [markdown]
# ### Converting to Datetime

# %%
d1 = ['2 June 2013', 'Aug 29, 2014', '2015-06-26', '7/12/16']
ts3 = pd.DataFrame(np.random.randint(10, 100, (4,2)), index=d1, columns=list('ab'))
ts3
# Out:
#                a   b
# 2 June 2013   65  32
# Aug 29, 2014  10  43
# 2015-06-26    76  32
# 7/12/16       44  99

# %%
#we can use to_datetime function to convert dataframe to standarad format.
ts3.index = pd.to_datetime(ts3.index)
ts3
# Out:
#              a   b
# 2013-06-02  65  32
# 2014-08-29  10  43
# 2015-06-26  76  32
# 2016-07-12  44  99

# %%
pd.to_datetime('4.7.12', dayfirst=True)
# Out:
# Timestamp('2012-07-04 00:00:00')

# %% [markdown]
# ### Timedeltas

# %%
#time deltas are differences in time.
pd.Timestamp('9/3/2016')-pd.Timestamp('9/1/2016')
# Out:
# Timedelta('2 days 00:00:00')

# %%
pd.Timestamp('9/2/2016 8:10AM') + pd.Timedelta('12D 3H')
# Out:
# Timestamp('2016-09-14 11:10:00')

# %% [markdown]
# ### Working with Dates in a Dataframe

# %%
dates = pd.date_range('10-01-2016', periods=9, freq='2W-SUN')
dates
# Out:
# DatetimeIndex(['2016-10-02', '2016-10-16', '2016-10-30', '2016-11-13',
#                '2016-11-27', '2016-12-11', '2016-12-25', '2017-01-08',
#                '2017-01-22'],
#               dtype='datetime64[ns]', freq='2W-SUN')

# %%
#The cumulative sum is not the cumulative sum of the values. Instead it is the cumulative sum of differences between the values and the average.
#cumsum() is the inbuilt function in numpy for cumulative sum.
df = pd.DataFrame({'Count 1': 100 + np.random.randint(-5, 10, 9).cumsum(),
                  'Count 2': 120 + np.random.randint(-5, 10, 9)}, index=dates)
df
# Out:
#             Count 1  Count 2
# 2016-10-02      106      129
# 2016-10-16      105      118
# 2016-10-30      110      129
# 2016-11-13      111      118
# 2016-11-27      113      119
# 2016-12-11      122      117
# 2016-12-25      126      128
# 2017-01-08      126      128
# 2017-01-22      127      121

# %%
df.index.weekday_name
# Out:
# Index(['Sunday', 'Sunday', 'Sunday', 'Sunday', 'Sunday', 'Sunday', 'Sunday',
#        'Sunday', 'Sunday'],
#       dtype='object')

# %%
#it gives difference between each day in a particular column
df.diff()
# Out:
#             Count 1  Count 2
# 2016-10-02      NaN      NaN
# 2016-10-16     -1.0    -11.0
# 2016-10-30      5.0     11.0
# 2016-11-13      1.0    -11.0
# 2016-11-27      2.0      1.0
# 2016-12-11      9.0     -2.0
# 2016-12-25      4.0     11.0
# 2017-01-08      0.0      0.0
# 2017-01-22      1.0     -7.0

# %%
#suppose if we want to find the mean count for each month in above data.
df.resample('M').mean()
# Out:
#             Count 1     Count 2
# 2016-10-31    107.0  125.333333
# 2016-11-30    112.0  118.500000
# 2016-12-31    124.0  122.500000
# 2017-01-31    126.5  124.500000

# %%
#data from a particular year
df['2017']
# Out:
#             Count 1  Count 2
# 2017-01-08      126      128
# 2017-01-22      127      121

# %%
df['2016-12']
# Out:
#             Count 1  Count 2
# 2016-12-11      122      117
# 2016-12-25      126      128

# %%
df['2016-12':]
# Out:
#             Count 1  Count 2
# 2016-12-11      122      117
# 2016-12-25      126      128
# 2017-01-08      126      128
# 2017-01-22      127      121

# %%
#using the asfreq you can change the frequency to weeks intead of 2W when we first defined it.
df.asfreq('W', method='ffill')
# Out:
#             Count 1  Count 2
# 2016-10-02      106      129
# 2016-10-09      106      129
# 2016-10-16      105      118
# 2016-10-23      105      118
# 2016-10-30      110      129
# 2016-11-06      110      129
# 2016-11-13      111      118
# 2016-11-20      111      118
# 2016-11-27      113      119
# 2016-12-04      113      119
# 2016-12-11      122      117
# 2016-12-18      122      117
# 2016-12-25      126      128
# 2017-01-01      126      128
# 2017-01-08      126      128
# 2017-01-15      126      128
# 2017-01-22      127      121

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

df.plot()

# %% [markdown]
# ### Distributions.

# %%
import pandas as pd
import numpy as np

# %%
#this function means a binomial distribution which is np.random.binomial(n,p,q) 
#where n=no of trials,p=probability of occurance and q=no of simulations.
np.random.binomial(1, 0.5)
# Out:
# 0

# %%
chance_of_tornado = 0.01/100   #this is infact the probability of tonado
np.random.binomial(100000, chance_of_tornado)
# Out:
# 12

# %%
chance_of_tornado = 0.01

tornado_events = np.random.binomial(1, chance_of_tornado, 1000000)
two_days_in_a_row = 0
for j in range(1,len(tornado_events)-1):
    if tornado_events[j]==1 and tornado_events[j-1]==1:
        two_days_in_a_row+=1

print('{} tornadoes back to back in {} years'.format(two_days_in_a_row, 1000000/365))
# Out:
# 99 tornadoes back to back in 2739.72602739726 years

# %%
#this function gives you a floating point numbers between 0 and 1
np.random.uniform(0, 1)
# Out:
# 0.21206084184675522

# %%
#this generates a normal distribution
np.random.normal(0.75)
# Out:
# 1.1091109953503575

# %% [markdown]
# Formula for standard deviation
# $$\sqrt{\frac{1}{N} \sum_{i=1}^N (x_i - \overline{x})^2}$$

# %%
distribution = np.random.normal(0.75,size=1000)

np.sqrt(np.sum((np.mean(distribution)-distribution)**2)/len(distribution))
# Out:
# 1.0302446600159754

# %%
np.std(distribution)
# Out:
# 1.0302446600159754

# %%
import scipy.stats as stats
stats.kurtosis(distribution)
# Out:
# 0.106565490633316

# %%
stats.skew(distribution)
# Out:
# -0.07072443878136932
